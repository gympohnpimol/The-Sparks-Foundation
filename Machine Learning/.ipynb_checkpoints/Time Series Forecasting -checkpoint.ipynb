# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('time_series.csv')
df[:5]
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df = df.dropna(how='any')

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code             float64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# dtype: object

# %%
ts = df.groupby('Order Date')['Sales'].sum().reset_index()
ts
# Out:
#      Order Date      Sales
# 0    2015-01-02   468.9000
# 1    2015-01-03  2203.1510
# 2    2015-01-04   119.8880
# 3    2015-01-06  5188.5200
# 4    2015-01-07   601.0240
# ...         ...        ...
# 1224 2018-12-26   814.5940
# 1225 2018-12-27   177.6360
# 1226 2018-12-28  1657.3508
# 1227 2018-12-29  2915.5340
# 1228 2018-12-30   713.7900
#
# [1229 rows x 2 columns]

# %%
ts = ts.set_index("Order Date")

# %%
ts
# Out:
#                 Sales
# Order Date
# 2015-01-02   468.9000
# 2015-01-03  2203.1510
# 2015-01-04   119.8880
# 2015-01-06  5188.5200
# 2015-01-07   601.0240
# ...               ...
# 2018-12-26   814.5940
# 2018-12-27   177.6360
# 2018-12-28  1657.3508
# 2018-12-29  2915.5340
# 2018-12-30   713.7900
#
# [1229 rows x 1 columns]

# %% [markdown]
# ## Time Series Analysis

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

plt.figure(figsize=(25,10))
plt.plot(ts.index, ts.Sales)

# %%
from pmdarima import auto_arima

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse

# %%
plt.rcParams.update({"figure.figsize":(10, 5), "figure.dpi":120})
plot_pacf(ts["Sales"].diff().dropna(), lags=100)

# %%
ts["Sales"].diff()
# Out:
# Order Date
# 2015-01-02          NaN
# 2015-01-03    1734.2510
# 2015-01-04   -2083.2630
# 2015-01-06    5068.6320
# 2015-01-07   -4587.4960
#                 ...
# 2018-12-26   -1884.3330
# 2018-12-27    -636.9580
# 2018-12-28    1479.7148
# 2018-12-29    1258.1832
# 2018-12-30   -2201.7440
# Name: Sales, Length: 1229, dtype: float64

# %%
plot_acf(ts["Sales"].diff().dropna(), lags=100)

# %%
sm.tsa.seasonal_decompose(ts["Sales"], freq=24).plot()
res = sm.tsa.stattools.adfuller(ts["Sales"])
plt.show()

# %% [markdown]
# auto_arima(ts['Sales'],
#            seasonal=True, m=12,max_p=7, max_d=5,max_q=7, max_P=4, max_D=4,max_Q=4).summary()

# %%
train_data = ts[:len(ts)-12]
test_data = ts[len(ts)-12:]

# %%
test_data
# Out:
#                 Sales
# Order Date
# 2018-12-19  1895.9260
# 2018-12-20   377.7360
# 2018-12-21  2140.9400
# 2018-12-22  7442.0210
# 2018-12-23  1926.7760
# 2018-12-24  6233.0540
# 2018-12-25  2698.9270
# 2018-12-26   814.5940
# 2018-12-27   177.6360
# 2018-12-28  1657.3508
# 2018-12-29  2915.5340
# 2018-12-30   713.7900

# %%
arima_model = SARIMAX(train_data["Sales"], order=(7,1,0), seasonal_order=(0,0,0,0))
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /usr/local/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
arima_result = arima_model.fit()
arima_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  Sales   No. Observations:                 1217
# Model:               SARIMAX(7, 1, 0)   Log Likelihood              -11177.044
# Date:                Wed, 17 Feb 2021   AIC                          22370.088
# Time:                        16:27:35   BIC                          22410.914
# Sample:                             0   HQIC                         22385.457
#                                - 1217
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8225      0.022    -37.177      0.000      -0.866      -0.779
# ar.L2         -0.6768      0.031    -22.056      0.000      -0.737      -0.617
# ar.L3         -0.5579      0.034    -16.491      0.000      -0.624      -0.492
# ...

# %%
arima_pred = arima_result.predict(start=len(train_data), end=len(ts)-1, typ="levels").rename("ARIMA Predictions")

arima_pred
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# 1217    2557.184687
# 1218    2236.495344
# 1219    2153.285294
# 1220    2138.127115
# 1221    1860.939345
# 1222    2127.253324
# 1223    2366.283691
# 1224    2409.156194
# 1225    2260.810752
# 1226    2220.907319
# 1227    2193.711469
# 1228    2173.398067
# Name: ARIMA Predictions, dtype: float64

# %%
test_data["Sales"].plot(figsize=(16,5), legend=True)

# %%
arima_pred.plot()

# %%
arima_rmse_error = rmse(test_data["Sales"], arima_pred)
print("arima_rmse_error:", arima_rmse_error)
# Out:
# arima_rmse_error: 2214.4902045777617

# %%
import math
arima_mse_error = math.sqrt(arima_rmse_error)
print("arima_mse_error:", arima_mse_error)
# Out:
# arima_mse_error: 47.05837018616095

# %%
mean_value = ts["Sales"].mean()
print("mean:", mean_value)
# Out:
# mean: 1832.8782853539437

# %% [markdown]
# ## LSTM Forecast

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaler.fit(train_data)
scaled_train_data = scaler.transform(train_data)
scaled_test_data = scaler.transform(test_data)

# %% [markdown]
# ### Create a time series generator

# %%
import tensorflow as tf

from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(scaled_train_data, scaled_train_data, 
                                length=n_input, batch_size=32)

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(200, activation="relu", input_shape=(n_input, n_features)))
lstm_model.add(Dense(1))
lstm_model.compile(optimizer="adam", loss="mse")

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 200)               161600
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# ...
# Total params: 161,801
# Trainable params: 161,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit_generator(generator, epochs=20)
# Out:
# Epoch 1/20
# 38/38 [==============================] - 1s 7ms/step - loss: 0.0077
# Epoch 2/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0062
# Epoch 3/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0063
# Epoch 4/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0059
# Epoch 5/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0071
# Epoch 6/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0062
# Epoch 7/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0064
# Epoch 8/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0052
# Epoch 9/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0072
# Epoch 10/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0055
# Epoch 11/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0063
# Epoch 12/20
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0077
# ...

# %%
losses_lstm = lstm_model.history.history["loss"]
plt.figure(figsize=(12,4))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(np.arange(0,21,1))
plt.plot(range(len(losses_lstm)), losses_lstm)

# %%
lstm_predictions_scaled = list()

batch = scaled_train_data[-n_input:]
current_batch = batch.reshape((1, n_input, n_features))

# %%
for i in range(len(test_data)):
    lstm_pred = lstm_model.predict(current_batch)[0]
    lstm_predictions_scaled.append(lstm_pred)
    current_batch = np.append(current_batch[:,1:,:], [[lstm_pred]], axis=1)

# %%
lstm_predictions_scaled
# Out:
# [array([0.07815727], dtype=float32),
#  array([0.07750295], dtype=float32),
#  array([0.07716794], dtype=float32),
#  array([0.0767574], dtype=float32),
#  array([0.07663158], dtype=float32),
#  array([0.07628941], dtype=float32),
#  array([0.0761536], dtype=float32),
#  array([0.07618023], dtype=float32),
#  array([0.07603534], dtype=float32),
#  array([0.07611242], dtype=float32),
#  array([0.0761475], dtype=float32),
#  array([0.07611094], dtype=float32)]

# %%
lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)
lstm_predictions
# Out:
# array([[2198.6108796 ],
#        [2180.22149017],
#        [2170.8059871 ],
#        [2159.26804347],
#        [2155.73175934],
#        [2146.11523585],
#        [2142.29836073],
#        [2143.04674298],
#        [2138.9748232 ],
#        [2141.14102757],
#        [2142.12707458],
#        [2141.09935771]])

# %%
test_data["LSTM_Predictions"] = lstm_predictions
test_data
